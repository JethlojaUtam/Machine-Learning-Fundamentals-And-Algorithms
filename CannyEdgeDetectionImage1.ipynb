# %%
import cv2
import matplotlib.pyplot as plt

#Loading an image
img=cv2.imread('Utam.jpg')
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY) #Edge detection works on intensity value, not on color, so BGR2GRAY is used

#Bluring on image using gaussianblur function
gaussian=cv2.GaussianBlur(img,(3,3),0)

#Canny(src,threshold1,threshold2)
canny=cv2.Canny(img,threshold1=20,threshold2=40)
canny_after_blur=cv2.Canny(gaussian,threshold1=20,threshold2=40)

#Ploting the image
plt.subplot(1,3,1),plt.imshow(img),plt.title('Source Image'),plt.axis('off')
plt.subplot(1,3,2),plt.imshow(canny,cmap='gray'),plt.title('Canny Image'),plt.axis('off')
plt.subplot(1,3,3),plt.imshow(canny_after_blur,cmap='gray'),plt.title('Canny-After-Blur Image'),plt.axis('off')
# Out:
# (<Axes: title={'center': 'Canny-After-Blur Image'}>,
# ...
#  Text(0.5, 1.0, 'Canny-After-Blur Image'),
#  (np.float64(-0.5), np.float64(2251.5), np.float64(3999.5), np.float64(-0.5)))
